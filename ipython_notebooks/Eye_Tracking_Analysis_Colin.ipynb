# %% [markdown]
# # Eye Tracking and Knowledge

# %%
import pandas as pd
import numpy as np
import string
import re
import time
import math
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
from decimal import *
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.cross_validation import KFold

from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn.lda import LDA
from sklearn.decomposition import PCA

# %% [markdown]
# ### Load gaze and pupil data

# %%
df_gaze = pd.read_csv('../data/logsAndEye_09152014.csv', na_values=['None'])
df_pupil = pd.read_csv('../data/pupilDiameters.csv', na_values=['None'])
# df_pupil.head()

# %% [markdown]
# ### Join datasets on subject_sync

# %%
# datasets are joined with rows containing null values dropped
df_all_data = df_gaze.merge(df_pupil, on='subject_sync').set_index('subject_sync').dropna()

# clean up column names (for pupil cols)
clean_columns = [name.replace(" ","_").replace("[","").replace("]","") for name in df_all_data.columns]
df_all_data.columns = clean_columns

# %%
# list of all columns
# [col for col in df_all_data.columns]

# %%
feature_cols = [
 'logs_Correct',
 'eye_switch',
 'eye_2ndFixDur_GR',
 'eye_2ndFixDur_Interactions',
 'eye_2ndFixDur_Titles',
 'eye_2ndFixDur_Hints', #
 'eye_2ndFixDur_Progress',
 'eye_2ndFixDur_WhiteSpace',
 'eye_1stFixDur_GR',
 'eye_1stFixDur_Interactions',
 'eye_1stFixDur_Titles',
 'eye_1stFixDur_Hints',
 'eye_1stFixDur_Progress',
 'eye_1stFixDur_WhiteSpace',
 'eye_fixDur_GR',
 'eye_fixDur_Interactions',
 'eye_fixDur_Titles',
 'eye_fixDur_Hints', #
 'eye_fixDur_Progress',
#  'eye_fixDur_WhiteSpace',
 'seq2_betweenGRs',
 'seq2_autoGR',
 'seq2_GR-caption',
 'seq2_GR-Interactions',
 'seq2_GR-HintText',
 'seq2_GR-Progress',
 'seq2_Interactions-Progress',
 'seq2_Interactions-HintText',
 'seq3_betweenGRs',
 'seq3_autoGR', #
#  'seq3_GR-caption-GR',
 'seq3_caption-GR-caption',
 'seq3_GR-Interactions-GR',
 'seq3_Interactions-GR-Interactions',
#  'seq3_GR-HintText-GR',
 'seq3_HintText-GR-HintText',
 'seq3_Interactions-HintText-Interactions',
 'seq3_HintText-Interactions-HintText',
 'seq3_GR-Progress-GR',
#  'seq3_Progress-GR-Progress',
#  'seq3_Progress-Interactions-Progress',
 'pretest_sense',
#  'posttest1_sense',
#  'posttest2_sense',
 'pretest_fluency',
#  'posttest1_fluency',
#  'posttest2_fluency',
 'pretest_concScales',
#  'posttest1_concScales',
#  'posttest2_concScales',
#  'prePost_concScales',
 'Average_Pupil_Diameter_mm',
 'AveragePupil_Size_px_X']

#choose an outcome variable
outcome_col = 'logs_errorRate_medianSplit' 
# oucome_col = 'logs_firstIncorrectRate_medianSplit'

df_features = df_all_data[feature_cols]
len(df_features)
# Out:
# 1234

# %% [markdown]
# ## Cross-validation function

# %%
# Cross-Validation Function
def cv_fun(pipeline):
    scores = []
    for train_idx, cv_idx in KFold(n=len(df_features), n_folds=7, indices=False, shuffle=True):
        train_features = df_features[train_idx]
        train_y    = np.asarray(df_all_data[train_idx][outcome_col])
        test_features  = df_features[cv_idx]
        test_y     = np.asarray(list(df_all_data[cv_idx][outcome_col]))
        pipeline.fit(train_features, train_y)
        score = pipeline.score(test_features, test_y)    
        scores.append(score)
    return scores, np.mean(scores)

# %%
# Refining Random Forest features

rf_feature_cols = [
 'logs_Correct',
 'eye_switch',
 'eye_2ndFixDur_GR',
 'eye_2ndFixDur_Interactions',
 'eye_2ndFixDur_Titles',
#  'eye_2ndFixDur_Hints', #
 'eye_2ndFixDur_Progress',
 'eye_2ndFixDur_WhiteSpace',
 'eye_1stFixDur_GR',
 'eye_1stFixDur_Interactions',
 'eye_1stFixDur_Titles',
 'eye_1stFixDur_Hints',
 'eye_1stFixDur_Progress',
 'eye_1stFixDur_WhiteSpace',
 'eye_fixDur_GR',
 'eye_fixDur_Interactions',
 'eye_fixDur_Titles',
#  'eye_fixDur_Hints', #
 'eye_fixDur_Progress',
 'eye_fixDur_WhiteSpace',
 'seq2_betweenGRs',
 'seq2_autoGR',
 'seq2_GR-caption',
 'seq2_GR-Interactions',
 'seq2_GR-HintText',
 'seq2_GR-Progress',
 'seq2_Interactions-Progress',
#  'seq2_Interactions-HintText',
#  'seq3_betweenGRs',
 'seq3_autoGR', #
 'seq3_GR-caption-GR',
 'seq3_caption-GR-caption',
#  'seq3_GR-Interactions-GR',
 'seq3_Interactions-GR-Interactions',
 'seq3_GR-HintText-GR',
 'seq3_HintText-GR-HintText',
 'seq3_Interactions-HintText-Interactions',
 'seq3_HintText-Interactions-HintText',
 'seq3_GR-Progress-GR',
 'seq3_Progress-GR-Progress',
 'seq3_Progress-Interactions-Progress',
 'pretest_sense',
#  'posttest1_sense',
#  'posttest2_sense',
 'pretest_fluency',
#  'posttest1_fluency',
#  'posttest2_fluency',
 'pretest_concScales',
#  'posttest1_concScales',
#  'posttest2_concScales',
#  'prePost_concScales',
 'Average_Pupil_Diameter_mm',
 'AveragePupil_Size_px_X']

df_rf_features = df_all_data[rf_feature_cols]


# Feature Importance with Random Forest / ExtraTreesClassifier and Cross-Validation
scores = []
for train_idx, cv_idx in KFold(n=len(df_rf_features), n_folds=8, indices=False, shuffle=True):
    train_features = df_rf_features[train_idx]
    train_y = np.asarray(df_all_data[train_idx][outcome_col])
    test_features  = df_rf_features[cv_idx]
    test_y = np.asarray(list(df_all_data[cv_idx][outcome_col]))

    importances = clf.feature_importances_
    for col, importance in zip(rf_feature_cols, importances):    
        if (importance > .03):
            print col, importance
        
    print len([i for i in importances if i < .01])
# Out:
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b90e0f618012> in <module>()
#      67     test_y = np.asarray(list(df_all_data[cv_idx][outcome_col]))
#      68
# ---> 69     importances = clf.feature_importances_
#      70     for col, importance in zip(rf_feature_cols, importances):
#      71         if (importance > .03):
#
# NameError: name 'clf' is not defined

# %%
df_features
# Out:
#                        logs_Correct  eye_switch  eye_2ndFixDur_GR  \
# subject_sync
# chem1_start_U1_I1_1              15         192              6160
# chem1_start_U1_I2_1              14         138              8858
# chem1_start_U3_I3_1                        444179                 27853
# chem10_start_U1_I1_1                        87169                  1623
# chem10_start_U1_I2_1                        59912                  2417
# chem10_start_U1_S1_1                        45989                  7887
# chem10_start_U1_S2_1                        70656                  9239
# chem10_start_U2_I1_1                        92950                  1679
# chem10_start_U2_I2_1                        81052                   979
# chem10_start_U2_S1_1                        48012                  6724
# chem10_start_U2_S2_1                        56479                  7559
# chem10_start_U3_I1_1                        96482                  2846
# chem10_start_U3_I2_1                       146311                  2096
# chem10_start_U3_S2_1                        33627                  5037
# chem100_start_U1_F1_1                           0                   820
# chem100_start_U1_F2_1                           0                   758
# chem100_start_U1_F3_1                           0                  1476
# chem100_start_U1_I1_1                      195971                  1526
# chem100_start_U1_I2_1                      106333                  2432
# chem100_start_U2_F1_1                           0                    56
# chem100_start_U2_F2_1                           0                     0
# chem100_start_U2_F3_1                           0                  3032
# chem100_start_U2_I1_1                      198885                  1700
# chem100_start_U2_I2_1                      160682                  3092
# ...                                           ...                   ...
# chem97_start_U3_I2_1                        68869                   756
# chem98_start_U1_F1_1                            0                     0
# chem98_start_U1_F2_1                            0                     0
# chem98_start_U1_I1_1                       132392                     0
# chem98_start_U1_I2_1                        77126                   150
# chem98_start_U2_F1_1                            0                   303
# chem98_start_U2_F2_1                            0                     0
# chem98_start_U2_F3_1                            0                   584
# chem98_start_U2_I1_1                       114282                   722
# chem98_start_U2_I2_1                       118112                    99
# chem98_start_U3_F1_1                            0                   155
# chem98_start_U3_F2_1                            0                     0
# chem98_start_U3_F3_1                            0                   287
# chem98_start_U3_I1_1                        26611                   791
# chem98_start_U3_I2_1                        79746                  1389
# chem99_start_U1_F1_1                            0                  9554
# chem99_start_U1_F2_1                            0                     0
# chem99_start_U1_F3_1                            0                   720
# chem99_start_U1_I1_1                        96150                  1271
# chem99_start_U1_I2_1                            0                     0
# chem99_start_U2_F1_1                            0                  1714
# chem99_start_U2_F2_1                            0                   119
# chem99_start_U2_F3_1                            0                   123
# chem99_start_U2_I1_1                       110443                   958
# chem99_start_U2_I2_1                       118377                  3532
# chem99_start_U3_F1_1                            0                   175
# chem99_start_U3_F2_1                            0                     0
# chem99_start_U3_F3_1                            0                     0
# chem99_start_U3_I1_1                        16100                     0
# chem99_start_U3_I2_1                        45045                  1026
#
#                        eye_2ndFixDur_Hints  eye_2ndFixDur_Progress  \
# subject_sync
# chem1_start_U1_I1_1                   9833                     759
# chem1_start_U1_I2_1                   4661                     131
# chem1_start_U1_I3_1                  16561                       0
# chem1_start_U2_I1_1                  10771                      63
# chem1_start_U2_I2_1                   4907                       0
# chem1_start_U2_I3_1                   3482                     283
# chem1_start_U3_I1_1                  12049                     391
# chem1_start_U3_I2_1                  32068                       0
# chem1_start_U3_I3_1                  87032                     184
# chem10_start_U1_I1_1                  6361                       0
# chem10_start_U1_I2_1                  1412                       0
# chem10_start_U1_S1_1                  5348                     654
# chem10_start_U1_S2_1                  4154                       0
# chem10_start_U2_I1_1                  3054                       0
# chem100_start_U1_F2_1                     11706               290
# chem100_start_U1_F3_1                     14120               467
# chem100_start_U1_I1_1                      2771               251
# chem100_start_U1_I2_1                       859               898
# chem100_start_U2_F1_1                     14481               342
# chem100_start_U2_F2_1                      6250               953
# chem100_start_U2_F3_1                     10064               650
# chem100_start_U2_I1_1                      1193               903
# chem100_start_U2_I2_1                      2058                52
# ...                                         ...               ...
# chem97_start_U3_I2_1                        411               322
# chem98_start_U1_F1_1                      17018               714
# chem98_start_U1_F2_1                       7541              1022
# chem98_start_U1_I1_1                       4028               165
# chem98_start_U1_I2_1                        196               103
# chem98_start_U2_F1_1                      11331              1289
# chem98_start_U2_F2_1                      14288               917
# chem98_start_U2_F3_1                      21724               714
# chem98_start_U2_I1_1                       2594               206
# chem98_start_U2_I2_1                       1036               179
# chem98_start_U3_F1_1                        545              1810
# chem98_start_U3_F2_1                       1753               312
# chem98_start_U3_F3_1                          0               662
# chem98_start_U3_I1_1                       3855              1643
# chem98_start_U3_I2_1                       4639               351
# chem99_start_U1_F1_1                      10692               617
# chem99_start_U1_F2_1                       8194               654
# chem99_start_U1_F3_1                       6094               725
# chem99_start_U1_I1_1                       1449               615
# chem99_start_U1_I2_1                      98047                 0
# chem99_start_U2_F1_1                       5933               525
# chem99_start_U2_F2_1                       6945               269
# chem99_start_U2_F3_1                       6813               440
# chem99_start_U2_I1_1                       1430               156
# chem99_start_U2_I2_1                       3889               175
# chem99_start_U3_F1_1                        444               302
# chem99_start_U3_F2_1                          0               674
# chem99_start_U3_F3_1                          0               892
# chem99_start_U3_I1_1                        526               145
# chem99_start_U3_I2_1                        597               126
#
#                        eye_1stFixDur_Interactions           ...            \
# subject_sync                                                ...
# chem1_start_U1_I1_1                           307           ...
# chem1_start_U1_I2_1                           115           ...
# chem1_start_U1_I3_1                           134           ...
# chem1_start_U2_I1_1                           112           ...
# chem1_start_U2_I2_1                           228           ...
# chem1_start_U2_I3_1                            91           ...
# chem1_start_U3_I1_1                           204           ...
# chem1_start_U3_I2_1                            84           ...
# chem1_start_U3_I3_1                           112           ...
# chem10_start_U1_I1_1                          151           ...
# chem10_start_U1_I2_1                           66           ...
# chem10_start_U1_S1_1                          101           ...
# chem10_start_U1_S2_1                           79           ...
# chem10_start_U2_I1_1                          191           ...
# chem10_start_U2_I2_1                           73           ...
# chem10_start_U2_S1_1                          183           ...
# chem10_start_U2_S2_1                          381           ...
# chem10_start_U3_I1_1                           95           ...
# chem10_start_U3_I2_1                          249           ...
# chem10_start_U3_S2_1                          243           ...
# chem100_start_U1_F1_1                           0           ...
# chem100_start_U1_F2_1                           0           ...
# chem100_start_U1_F3_1                           0           ...
# chem100_start_U1_I1_1                         357           ...
# chem100_start_U1_I2_1                          80           ...
# chem100_start_U2_F1_1                           0           ...
# chem100_start_U2_F2_1                           0           ...
# chem100_start_U2_F3_1                           0           ...
# chem100_start_U2_I1_1                         175           ...
# chem100_start_U2_I2_1                          68           ...
# ...                                           ...           ...
# chem97_start_U3_I2_1                          191           ...
# chem98_start_U1_F1_1                            0           ...
# chem98_start_U1_F2_1                            0           ...
# chem98_start_U1_I1_1                          147           ...
# chem98_start_U1_I2_1                          311           ...
# chem98_start_U2_F1_1                            0           ...
# chem98_start_U2_F2_1                            0           ...
# chem98_start_U2_F3_1                            0           ...
# chem98_start_U2_I1_1                          388           ...
# chem98_start_U2_I2_1                          355           ...
# chem98_start_U3_F1_1                            0           ...
# chem98_start_U3_F2_1                            0           ...
# chem98_start_U3_F3_1                            0           ...
# chem98_start_U3_I1_1                          127           ...
# chem98_start_U3_I2_1                           72           ...
# chem99_start_U1_F1_1                            0           ...
# chem99_start_U1_F2_1                            0           ...
# chem99_start_U1_F3_1                            0           ...
# chem99_start_U1_I1_1                          103           ...
# chem99_start_U1_I2_1                            0           ...
# chem99_start_U2_F1_1                            0           ...
# chem99_start_U2_F2_1                            0           ...
# chem99_start_U2_F3_1                            0           ...
# chem99_start_U2_I1_1                           95           ...
# chem99_start_U2_I2_1                          151           ...
# chem99_start_U3_F1_1                            0           ...
# chem99_start_U3_F2_1                            0           ...
# chem99_start_U3_F3_1                            0           ...
# chem99_start_U3_I1_1                          127           ...
# chem99_start_U3_I2_1                          180           ...
#
#                        seq3_Interactions-GR-Interactions  \
# subject_sync
# chem1_start_U1_I1_1                                   12
# chem1_start_U1_I2_1                                    5
# chem1_start_U1_I3_1                                    7
# chem1_start_U2_I1_1                                    9
# chem1_start_U2_I2_1                                   10
# chem1_start_U2_I3_1                                    5
# chem1_start_U3_I1_1                                    8
# chem1_start_U3_I2_1                                    8
# chem1_start_U3_I3_1                                   30
# chem10_start_U1_I1_1                                   8
# chem10_start_U1_I2_1                                   5
# chem10_start_U1_S1_1                                  10
# chem10_start_U1_S2_1                                  14
# chem10_start_U2_I1_1                                  10
# chem10_start_U2_I2_1                                  12
# chem10_start_U2_S1_1                                  13
# chem10_start_U2_S2_1                                   6
# chem10_start_U3_I1_1                                  12
# chem10_start_U3_I2_1                                   9
# chem10_start_U3_S2_1                                   3
# chem100_start_U1_F1_1                                  0
# chem100_start_U1_F2_1                                  0
# chem100_start_U1_F3_1                                  0
# chem100_start_U1_I1_1                                  7
# chem100_start_U1_I2_1                                  3
# chem100_start_U2_F1_1                                  0
# chem100_start_U2_F2_1                                  0
# chem100_start_U2_F3_1                                  0
# chem100_start_U2_I1_1                                  8
# chem100_start_U2_I2_1                                  8
# ...                                                  ...
# chem97_start_U3_I2_1                                   5
# chem98_start_U1_F1_1                                   0
# chem98_start_U1_F2_1                                   0
# chem98_start_U1_I1_1                                   3
# chem98_start_U1_I2_1                                   7
# chem98_start_U2_F1_1                                   0
# chem98_start_U2_F2_1                                   0
# chem98_start_U2_F3_1                                   0
# chem98_start_U2_I1_1                                   2
# chem98_start_U2_I2_1                                   6
# chem98_start_U3_F1_1                                   0
# chem98_start_U3_F2_1                                   0
# chem98_start_U3_F3_1                                   0
# chem98_start_U3_I1_1                                   0
# chem1_start_U2_I1_1                                          3
# chem1_start_U2_I2_1                                          1
# chem1_start_U2_I3_1                                          3
# chem1_start_U3_I1_1                                          2
# chem1_start_U3_I2_1                                          4
# chem1_start_U3_I3_1                                          7
# chem10_start_U1_I1_1                                         0
# chem10_start_U1_I2_1                                         0
# chem10_start_U1_S1_1                                         0
# chem10_start_U1_S2_1                                         0
# chem10_start_U2_I1_1                                         0
# chem10_start_U2_I2_1                                         0
# chem10_start_U2_S1_1                                         0
# chem10_start_U2_S2_1                                         0
# chem10_start_U3_I1_1                                         0
# chem10_start_U3_I2_1                                         0
# chem10_start_U3_S2_1                                         0
# chem100_start_U1_F1_1                                        0
# chem100_start_U1_F2_1                                        0
# chem100_start_U1_F3_1                                        0
# chem100_start_U1_I1_1                                        2
# chem100_start_U1_I2_1                                        2
# chem100_start_U2_F1_1                                        0
# chem100_start_U2_F2_1                                        0
# chem100_start_U2_F3_1                                        0
# chem100_start_U2_I1_1                                        0
# chem100_start_U2_I2_1                                        0
# ...                                                        ...
# chem97_start_U3_I2_1                                         3
# chem98_start_U1_F1_1                                         0
# chem98_start_U1_F2_1                                         0
# chem98_start_U1_I1_1                                         1
# chem98_start_U1_I2_1                                         1
# chem98_start_U2_F1_1                                         0
# chem98_start_U2_F2_1                                         0
# chem98_start_U2_F3_1                                         0
# chem98_start_U2_I1_1                                         2
# chem98_start_U2_I2_1                                         1
# chem98_start_U3_F1_1                                         0
# chem98_start_U3_F2_1                                         0
# chem98_start_U3_F3_1                                         0
# chem98_start_U3_I1_1                                         2
# chem98_start_U3_I2_1                                         1
# chem99_start_U1_F1_1                                         0
# chem99_start_U1_F2_1                                         0
# chem99_start_U1_F3_1                                         0
# chem99_start_U1_I1_1                                         1
# chem99_start_U1_I2_1                                         0
# chem99_start_U2_F1_1                                         0
# chem99_start_U2_F2_1                                         0
# chem99_start_U2_F3_1                                         0
# chem99_start_U2_I1_1                                         0
# chem99_start_U2_I2_1                                         0
# chem99_start_U3_F1_1                                         0
# chem99_start_U3_F2_1                                         0
# chem99_start_U3_F3_1                                         0
# chem99_start_U3_I1_1                                         0
# chem99_start_U3_I2_1                                         2
#
#                        seq3_HintText-Interactions-HintText  \
# subject_sync
# chem1_start_U1_I1_1                                      0
# chem1_start_U1_I2_1                                      0
# chem1_start_U1_I3_1                                      0
# chem1_start_U2_I1_1                                      0
# chem1_start_U2_I2_1                                      2
# chem1_start_U2_I3_1                                      0
# chem1_start_U3_I1_1                                      2
# chem1_start_U3_I2_1                                      4
# chem1_start_U3_I3_1                                      4
# chem10_start_U1_I1_1                                     0
# chem10_start_U1_I2_1                                     0
# chem10_start_U1_S1_1                                     0
# chem10_start_U1_S2_1                                     0
# chem10_start_U2_I1_1                                     0
# chem10_start_U2_I2_1                                     0
# chem10_start_U2_S1_1                                     0
# chem10_start_U2_S2_1                                     0
# chem10_start_U3_I1_1                                     0
# chem10_start_U3_I2_1                                     0
# chem10_start_U3_S2_1                                     0
# chem100_start_U1_F1_1                                    0
# chem100_start_U1_F2_1                                    0
# chem100_start_U1_F3_1                                    0
# chem100_start_U1_I1_1                                    0
# chem100_start_U1_I2_1                                    1
# chem100_start_U2_F1_1                                    0
# chem100_start_U2_F2_1                                    0
# chem100_start_U2_F3_1                                    0
# chem100_start_U2_I1_1                                    1
# chem100_start_U2_I2_1                                    0
# ...                                                    ...
# chem97_start_U3_I2_1                                     0
# chem98_start_U1_F1_1                                     0
# chem98_start_U1_F2_1                                     0
# chem98_start_U1_I1_1                                     0
# chem98_start_U1_I2_1                                     0
# chem98_start_U2_F1_1                                     0
# chem98_start_U2_F2_1                                     0
# chem98_start_U2_F3_1                                     0
# chem98_start_U2_I1_1                                     0
# chem98_start_U2_I2_1                                     0
# chem98_start_U3_F1_1                                     0
# chem98_start_U3_F2_1                                     0
# chem98_start_U3_F3_1                                     0
# chem98_start_U3_I1_1                                     0
# chem98_start_U3_I2_1                                     0
# chem99_start_U1_F1_1                                     0
# chem99_start_U1_F2_1                                     0
# chem99_start_U1_F3_1                                     0
# chem99_start_U1_I1_1                                     0
# chem99_start_U1_I2_1                                     0
# chem99_start_U2_F1_1                                     0
# chem99_start_U2_F2_1                                     0
# chem99_start_U2_F3_1                                     0
# chem99_start_U2_I1_1                                     0
# chem99_start_U2_I2_1                                     0
# chem99_start_U3_F1_1                                     0
# chem99_start_U3_F2_1                                     0
# chem99_start_U3_F3_1                                     0
# chem99_start_U3_I1_1                                     0
# chem99_start_U3_I2_1                                     0
#
#                        seq3_GR-Progress-GR  pretest_sense  pretest_fluency  \
# subject_sync
# chem1_start_U1_I1_1                      0       0.275000             0.75
# chem1_start_U1_I2_1                      0       0.275000             0.75
# chem1_start_U1_I3_1                      0       0.275000             0.75
# chem1_start_U2_I1_1                      0       0.275000             0.75
# chem1_start_U2_I2_1                      0       0.275000             0.75
# chem1_start_U2_I3_1                      0       0.275000             0.75
# chem1_start_U3_I1_1                      0       0.275000             0.75
# chem1_start_U3_I2_1                      0       0.275000             0.75
# chem1_start_U3_I3_1                      0       0.275000             0.75
# chem10_start_U1_I1_1                     0       0.591667             0.75
# chem10_start_U1_I2_1                     0       0.591667             0.75
# chem10_start_U1_S1_1                     1       0.591667             0.75
# chem10_start_U1_S2_1                     0       0.591667             0.75
# chem10_start_U2_I1_1                     0       0.591667             0.75
# chem10_start_U2_I2_1                     0       0.591667             0.75
# chem10_start_U2_S1_1                     0       0.591667             0.75
# chem10_start_U2_S2_1                     0       0.591667             0.75
# chem10_start_U3_I1_1                     0       0.591667             0.75
# chem10_start_U3_I2_1                     0       0.591667             0.75
# chem10_start_U3_S2_1                     0       0.591667             0.75
# chem100_start_U1_F1_1                    0       0.641667             0.75
# chem100_start_U1_F2_1                    1       0.641667             0.75
# chem100_start_U1_F3_1                    0       0.641667             0.75
# chem100_start_U1_I1_1                    0       0.641667             0.75
# chem100_start_U1_I2_1                    0       0.641667             0.75
# chem100_start_U2_F1_1                    1       0.641667             0.75
# chem100_start_U1_F3_1               12.128958
# chem100_start_U1_I1_1               12.207835
# chem100_start_U1_I2_1               12.603456
# chem100_start_U2_F1_1               12.108955
# chem100_start_U2_F2_1               11.803061
# chem100_start_U2_F3_1               12.148413
# chem100_start_U2_I1_1               12.315217
# chem100_start_U2_I2_1               12.471390
# ...                                       ...
# chem97_start_U3_I2_1                13.953666
# chem98_start_U1_F1_1                16.340598
# chem98_start_U1_F2_1                16.489877
# chem98_start_U1_I1_1                15.869217
# chem98_start_U1_I2_1                16.517881
# chem98_start_U2_F1_1                16.364014
# chem98_start_U2_F2_1                16.593772
# chem98_start_U2_F3_1                16.875155
# chem98_start_U2_I1_1                16.236986
# chem98_start_U2_I2_1                16.398035
# chem98_start_U3_F1_1                14.261905
# chem98_start_U3_F2_1                13.691304
# chem98_start_U3_F3_1                13.636842
# chem98_start_U3_I1_1                14.084795
# chem98_start_U3_I2_1                13.537941
# chem99_start_U1_F1_1                13.847222
# chem99_start_U1_F2_1                13.779282
# chem99_start_U1_F3_1                14.032979
# chem99_start_U1_I1_1                14.637446
# chem99_start_U1_I2_1                14.477507
# chem99_start_U2_F1_1                14.444474
# chem99_start_U2_F2_1                14.710469
# chem99_start_U2_F3_1                15.204000
# chem99_start_U2_I1_1                15.120474
# chem99_start_U2_I2_1                15.553719
# chem99_start_U3_F1_1                16.513043
# chem99_start_U3_F2_1                16.066667
# chem99_start_U3_F3_1                16.007692
# chem99_start_U3_I1_1                16.339437
# chem99_start_U3_I2_1                16.679429
#
# [1234 rows x 41 columns]

# %% [markdown]
# ## Classification pipelines

# %%
def nb(df_train):
    pipeline = Pipeline([
        #('scaler', StandardScaler()),
        #('reduce_dim', PCA()),
        #('reduce_dim', LDA()),
        ('clf', GaussianNB())
    ])
    result = cv_fun(pipeline=pipeline)
    print "NB average score:", result[1]
    print "NB scores:", result[0]
    print "stddev:", np.std(result[0]) 
#     print "range:", np.max(result[0]) - np.min(result[0])
    print
    
    
def max_ent(df_train):
    pipeline = Pipeline([
        #('scaler', StandardScaler()),
        #('reduce_dim', PCA()),
        #('reduce_dim', LDA()),
        ('clf', LogisticRegression(penalty='l2'))
    ])
    result = cv_fun(pipeline=pipeline)
    print "MaxEnt average score:", result[1]
    print "MaxEnt scores:", result[0]
    print "stddev:", np.std(result[0])
#     print "range:", np.max(result[0]) - np.min(result[0])
    print

    
def random_forest(df_train):
    pipeline = Pipeline([
        #('scaler', StandardScaler()),
        #('reduce_dim', PCA()),
        #('reduce_dim', LDA()),
        ('feature_selection', ExtraTreesClassifier()), # need way to print this, see which features picked
        ('clf', RandomForestClassifier())
    ])
    result = cv_fun(pipeline=pipeline)
    print "RF average score:", result[1]
    print "RF scores:", result[0]
    print "stddev:", np.std(result[0])
#     print "range:", np.max(result[0]) - np.min(result[0])
    print

# %%
# Evaluate scores across k folds

# currently, features chosen using feature selection for RF, so not surprising that Naive Bayes
# is not doing very well

nb(df_features)
max_ent(df_features)
random_forest(df_features)
# Out:
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# NB average score: 0.586694731822
# NB scores: [0.56497175141242939, 0.6271186440677966, 0.57954545454545459, 0.56818181818181823, 0.57954545454545459, 0.60795454545454541, 0.57954545454545459]
# stddev: 0.0208875379901
#
# MaxEnt average score:
#  0.640999889941
# MaxEnt scores: [0.62146892655367236, 0.66666666666666663, 0.60227272727272729, 0.65909090909090906, 0.65909090909090906, 0.61931818181818177, 0.65909090909090906]
# stddev: 0.0238806151974
#
# RF average score:
#  0.642568236848
# RF scores: [0.67231638418079098, 0.68361581920903958, 0.64772727272727271, 0.63636363636363635, 0.60227272727272729, 0.64204545454545459, 0.61363636363636365]
# stddev: 0.0269815378324
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)

# %%
NB = .588
ME = .64
RF = .69

# %% [markdown]
# ##Research Questions
#
# 1. What are the features of eye tracking that best predict performance?
#
# 2. Multiple representations of concepts were provided within the tutor. Can an analysis make recommendations about the efficacy of each representation?
#
# 3. Can we predict learning (Post-Pre knowledge) from eye tracking features?

# %%
# Next TODOs:

# Go back and inspect which rows were dropped with dropna(). Other outliers we need to take care of?

# Improve feature selection to find most informative features
# http://scikit-learn.org/stable/modules/feature_selection.html

# %% [markdown]
# Check predictive measure of pre-test for top x percent vs. bottom x percent
#
# K means k2 through k8 and binary features / spectral clustering
#   does one clustering do better than the other
#   test each k to see which is best, find feature break down of each cluster in best k
#
# compare just clusters, just features, and both for predictions
#
# gaze behavior profile (pattern)

# %% [markdown]
# ## Clusters

# %%
gaze_cols = [
 'logs_Correct',
 'eye_switch',
 'eye_2ndFixDur_GR',
 'eye_2ndFixDur_Interactions',
 'eye_2ndFixDur_Titles',
 'eye_2ndFixDur_Hints', 
 'eye_2ndFixDur_Progress',
 'eye_2ndFixDur_WhiteSpace',
 'eye_1stFixDur_GR',
 'eye_1stFixDur_Interactions',
 'eye_1stFixDur_Titles',
 'eye_1stFixDur_Hints',
 'eye_1stFixDur_Progress',
 'eye_1stFixDur_WhiteSpace',
 'eye_fixDur_GR',
 'eye_fixDur_Interactions',
 'eye_fixDur_Titles',
 'eye_fixDur_Hints', 
 'eye_fixDur_Progress',
 'eye_fixDur_WhiteSpace',
 'seq2_betweenGRs',
 'seq2_autoGR',
 'seq2_GR-caption',
 'seq2_GR-Interactions',
 'seq2_GR-HintText',
 'seq2_GR-Progress',
 'seq2_Interactions-Progress',
 'seq2_Interactions-HintText',
 'seq3_betweenGRs',
 'seq3_autoGR', 
 'seq3_GR-caption-GR',
 'seq3_caption-GR-caption',
 'seq3_GR-Interactions-GR',
 'seq3_Interactions-GR-Interactions',
 'seq3_GR-HintText-GR',
 'seq3_HintText-GR-HintText',
 'seq3_Interactions-HintText-Interactions',
 'seq3_HintText-Interactions-HintText',
 'seq3_GR-Progress-GR',
 'seq3_Progress-GR-Progress',
 'seq3_Progress-Interactions-Progress']

# %%
from sklearn.cluster import KMeans

df_gaze_features = df_all_data[gaze_cols]
df_cluster_features = pd.DataFrame(index=df_gaze_features.index)

for n in xrange(2,9):
    k_means = KMeans(init='k-means++', n_clusters=n, n_init=10)
    k_means.fit(df_gaze_features)
    k_means_labels = k_means.labels_
    k_means_cluster_centers = k_means.cluster_centers_
    k_means_labels_unique = np.unique(k_means_labels)
    
    #create dataframe with cluster
    for cluster in xrange(n):
        label = 'k%d_%d' % (n, cluster)
        df_cluster_features[label] = [1 if x == cluster else 0 for x in k_means_labels]

# %%
len(df_cluster_features)- len(df_features)
# Out:
# 0

# %%
# add new features to full data
df_features_clusters = df_features.join(df_cluster_features)

# %%
#clusters alone
nb(df_cluster_features)
max_ent(df_cluster_features)
random_forest(df_cluster_features)
# Out:
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# NB average score: 0.589152725805
# NB scores: [0.55932203389830504, 0.60451977401129942, 0.56818181818181823, 0.60795454545454541, 0.52272727272727271, 0.63636363636363635, 0.625]
# stddev: 0.0375034126037
#
# MaxEnt average score:
#  0.644232885758
# MaxEnt scores: [0.66101694915254239, 0.64406779661016944, 0.625, 0.60795454545454541, 0.67045454545454541, 0.63636363636363635, 0.66477272727272729]
# stddev: 0.0211766027254
#
# RF average score:
#  0.640142343532
# RF scores: [0.6271186440677966, 0.71751412429378536, 0.61363636363636365, 0.625, 0.60795454545454541, 0.65340909090909094, 0.63636363636363635]
# stddev: 0.0344636585048
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)

# %%
#conbined with cluster
nb(df_features_clusters)
max_ent(df_features_clusters)
random_forest(df_features_clusters)
# Out:
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)
# NB average score: 0.585121799105
# NB scores: [0.5536723163841808, 0.57627118644067798, 0.60795454545454541, 0.53409090909090906, 0.59090909090909094, 0.64772727272727271, 0.58522727272727271]
# stddev: 0.0341129186841
#
# MaxEnt average score:
#  0.640963203463
# MaxEnt scores: [0.66101694915254239, 0.67231638418079098, 0.67045454545454541, 0.64204545454545459, 0.60227272727272729, 0.625, 0.61363636363636365]
# stddev: 0.02606206374
#
# RF average score:
#  0.662883373688
# RF scores: [0.66101694915254239, 0.66666666666666663, 0.65340909090909094, 0.65909090909090906, 0.71590909090909094, 0.60795454545454541, 0.67613636363636365]
# stddev: 0.0295839876301
# /Users/colingerber/Documents/I_School_Classes/Edu_Machine/Final_Project/Edu_ML_Final_Project/env/lib/python2.7/site-packages/sklearn/cross_validation.py:65: DeprecationWarning: The indices parameter is deprecated and will be removed (assumed True) in 0.17
#   stacklevel=1)

# %%
df_gaze_features = df_all_data[gaze_cols]
scaler = StandardScaler().fit(df_gaze_features)

# %%
scaler.transform(df_gaze_features)
# Out:
# array([[-0.04669315,  0.99880212, -0.63414118, ..., -0.31111316,
#         -0.10619816, -0.28753314],
#        [-0.20945967,  0.22640369, -0.53107029, ..., -0.31111316,
#         -0.10619816, -0.28753314],
#        [ 0.44160641,  1.42791236, -0.68762497, ..., -0.31111316,
#         -0.10619816, -0.28753314],
#        ...,
#        [-0.86052575, -1.63307402, -0.82679741, ..., -0.31111316,
#         -0.10619816, -0.28753314],
#        [ 0.44160641, -1.4185189 , -0.82809631, ..., -0.31111316,
#         -0.10619816, -0.28753314],
#        [ 1.74373856, -1.38991155, -0.81896586, ..., -0.31111316,
#         -0.10619816, -0.28753314]])
